# %% [markdown]
# # Hypertuning

# %% [markdown]
# **Import train, val, test sets from Google Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
drive_path = '/content/drive/MyDrive/Colab Notebooks/'
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import polars as pl
from datetime import timedelta
import os

# %%
df_train = pl.read_parquet(os.path.join(drive_path, "df_train.parquet"))
df_val = pl.read_parquet(os.path.join(drive_path, "df_val.parquet"))

# %%
df_train.head()
# Out:
# shape: (5, 39)
# ┌──────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ Time     ┆ Date      ┆ Sender_ac ┆ Receiver_ ┆ … ┆ weekly_re ┆ daily_sen ┆ weekly_se ┆ circular_ │
# │ ---      ┆ ---       ┆ count     ┆ account   ┆   ┆ ceiver_tr ┆ der_trans ┆ nder_tran ┆ transacti │
# │ time     ┆ date      ┆ ---       ┆ ---       ┆   ┆ ansaction ┆ action    ┆ saction   ┆ on_count  │
# │          ┆           ┆ i64       ┆ i64       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │          ┆           ┆           ┆           ┆   ┆ i16       ┆ i16       ┆ i16       ┆ i8        │
# ╞══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 10:35:34 ┆ 2022-10-0 ┆ 560602477 ┆ 864619375 ┆ … ┆ 1         ┆ 1         ┆ 1         ┆ 0         │
# │          ┆ 7         ┆ 5         ┆ 9         ┆   ┆           ┆           ┆           ┆           │
# │ 10:36:04 ┆ 2022-10-0 ┆ 200413348 ┆ 307981854 ┆ … ┆ 68        ┆ 11        ┆ 11        ┆ 0         │
# │          ┆ 7         ┆ 4         ┆ 7         ┆   ┆           ┆           ┆           ┆           │
# │ 10:36:31 ┆ 2022-10-0 ┆ 408255279 ┆ 417319509 ┆ … ┆ 74        ┆ 12        ┆ 12        ┆ 0         │
# │          ┆ 7         ┆ 8         ┆ 4         ┆   ┆           ┆           ┆           ┆           │
# │ 10:37:15 ┆ 2022-10-0 ┆ 35328673  ┆ 179459555 ┆ … ┆ 1         ┆ 1         ┆ 3         ┆ 0         │
# │          ┆ 7         ┆           ┆ 5         ┆   ┆           ┆           ┆           ┆           │
# │ 10:37:41 ┆ 2022-10-0 ┆ 718912811 ┆ 434450472 ┆ … ┆ 1         ┆ 1         ┆ 1         ┆ 0         │
# │          ┆ 7         ┆ 9         ┆ 8         ┆   ┆           ┆           ┆           ┆           │
# └──────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %% [markdown]
# **XGBoost**

# %%
import xgboost as xgb
from xgboost import XGBClassifier
from sklearn.metrics import f1_score, accuracy_score, confusion_matrix, classification_report, roc_auc_score, precision_score, recall_score
import itertools
import pandas as pd

# %%
opt_features = ["Amount", "year", "day_of_month", "day_of_week", "hour", "minute", "second",
            "currency_mismatch", "high_risk_sender", "high_risk_receiver",
            "fanin_30d", "fanin_intensity_ratio",
            "sent_to_received_ratio_monthly", "back_and_forth_transfers",
            "circular_transaction_count", "Is_laundering"]

# %%
# Configuration
features = opt_features[:-1]
target = opt_features[-1]
use_gpu = False             # set True if you have GPU and xgboost built with GPU support
early_stopping_rounds = 50
num_boost_round = 500
verbose_eval = False        # set to integer for logging every k rounds

# %%
# 1) Convert Polars -> NumPy once (casting to float32)
#    Handle missing values and simple categorical encoding if needed.
def polars_to_numpy_for_xgb(df_pl: pl.DataFrame, features, target):
    # Ensure numeric features; cast numeric-like to Float32
    X_df = df_pl.select([pl.col(c).cast(pl.Float32).alias(c) for c in features])
    y_arr = df_pl.select(pl.col(target)).to_numpy().ravel()
    X_arr = X_df.to_numpy()
    return X_arr, y_arr

X_train, y_train = polars_to_numpy_for_xgb(df_train, features, target)
X_val, y_val = polars_to_numpy_for_xgb(df_val, features, target)

# %%
# 2) Build DMatrix once per dataset (faster than rebuilding inside loop)
dtrain = xgb.DMatrix(X_train, label=y_train, feature_names=features)
dval = xgb.DMatrix(X_val, label=y_val, feature_names=features)
watchlist = [(dtrain, "train"), (dval, "eval")]

# %%
param_grid = {
    'max_depth': [3, 5, 10],
    'learning_rate': [0.1, 0.05, 0.01],
    'subsample': [0.3, 0.5, 1]
}

# %%
def predict_with_best_iter(bst, dmat):
    # bst.best_iteration is int (0-based). If None, predict full model.
    best_it = getattr(bst, "best_iteration", None)
    if best_it is None:
        return bst.predict(dmat)
    # iteration_range expects (begin, end) with end exclusive
    return bst.predict(dmat, iteration_range=(0, best_it + 1))

    # inside your loop, replace prediction section with:
    #preds_proba = predict_with_best_iter(bst, dval)
    #preds = (preds_proba > 0.5).astype(int)

# %%
import time

# 3) Optimized grid search loop using xgb.train
results = []
start_all = time.time()

for max_depth, lr, subs in itertools.product(
        param_grid['max_depth'],
        param_grid['learning_rate'],
        param_grid['subsample']):

    params = {
        "max_depth": int(max_depth),
        "eta": float(lr),                 # alias for learning_rate in xgb.train params
        "subsample": float(subs),
        "objective": "binary:logistic",
        "eval_metric": "logloss",
        "seed": 42,
        "verbosity": 0,
        "nthread": -1
    }
    if use_gpu:
        params["tree_method"] = "gpu_hist"
        params["predictor"] = "gpu_predictor"
    else:
        params["tree_method"] = "hist"

    t0 = time.time()
    bst = xgb.train(
        params,
        dtrain,
        num_boost_round=num_boost_round,
        evals=watchlist,
        early_stopping_rounds=early_stopping_rounds,
        verbose_eval=verbose_eval
    )
    t1 = time.time()

    # predictions on validation (use best_ntree_limit if early stopping occurred)
    preds_proba = predict_with_best_iter(bst, dval)
    preds = (preds_proba > 0.5).astype(int)

    f1 = f1_score(y_val, preds)
    prec = precision_score(y_val, preds)
    rec = recall_score(y_val, preds)
    report = classification_report(y_val, preds, digits=4)

    results.append({
        "max_depth": int(max_depth),
        "learning_rate": float(lr),
        "subsample": float(subs),
        "f1_score": f1,
        "precision_score": prec,
        "recall_score": rec,
        "report": report,
        "model": bst,
        "train_time_s": t1 - t0
    })

total_time = time.time() - start_all

# 4) Convert to pandas DataFrame and sort by f1 (descending)
df_results = pd.DataFrame([{k:v for k,v in r.items() if k != "model"} for r in results])
df_results = df_results.sort_values("f1_score", ascending=False).reset_index(drop=True)

# Best model and params
best = results[df_results.index[0]]
best_params = {"max_depth": best["max_depth"], "learning_rate": best["learning_rate"], "subsample": best["subsample"]}
best_model = best["model"]

# 5) Reporting
print(f"Grid search finished in {total_time:.1f}s, tried {len(results)} combos")
print("Top 5 combos by F1:")
print(df_results.head(10))
print("\nBest combo:", best_params)
print("\nClassification report for best model:")
print(best["report"])
# Out:
# Grid search finished in 9579.2s, tried 27 combos
# Top 5 combos by F1:
#    max_depth  learning_rate  subsample  f1_score  precision_score  \
# 0         10           0.01        1.0  0.526973         0.821239
# 1         10           0.01        0.5  0.524741         0.841328
# 2          5           0.05        1.0  0.522952         0.857143
# 3          5           0.05        0.3  0.520612         0.880478
# 4          5           0.10        1.0  0.519864         0.809187
# 5          5           0.05        0.5  0.519511         0.856046
# 6          3           0.10        0.5  0.518913         0.885081
# 7         10           0.05        0.5  0.517755         0.821818
# 8         10           0.05        1.0  0.517514         0.797909
# 9         10           0.01        0.3  0.516919         0.855212
#
#    recall_score                                             report  \
# 0      0.387960                precision    recall  f1-score   ...
# 1      0.381271                precision    recall  f1-score   ...
# 2      0.376254                precision    recall  f1-score   ...
# 3      0.369565                precision    recall  f1-score   ...
# 4      0.382943                precision    recall  f1-score   ...
# 5      0.372910                precision    recall  f1-score   ...
# 6      0.367057                precision    recall  f1-score   ...
# 7      0.377926                precision    recall  f1-score   ...
# 8      0.382943                precision    recall  f1-score   ...
# 9      0.370401                precision    recall  f1-score   ...
#
#    train_time_s
# 0    585.976552
# 1    603.601475
# 2    336.453116
# 3    364.551504
# 4    249.431554
# 5    401.940874
# 6    329.496894
# 7    241.418152
# 8    190.084901
# 9    601.456531
#
# Best combo: {'max_depth': 3, 'learning_rate': 0.1, 'subsample': 0.3}
#
# Classification report for best model:
#               precision    recall  f1-score   support
#
#            0     0.9993    0.9999    0.9996   1043649
#            1     0.8477    0.3537    0.4991      1196
#
#     accuracy                         0.9992   1044845
#    macro avg     0.9235    0.6768    0.7494   1044845
# weighted avg     0.9991    0.9992    0.9990   1044845

# %%
df_results
# Out:
#     max_depth  learning_rate  subsample  f1_score  precision_score  \
# 0          10           0.01        1.0  0.526973         0.821239
# 1          10           0.01        0.5  0.524741         0.841328
# 2           5           0.05        1.0  0.522952         0.857143
# 3           5           0.05        0.3  0.520612         0.880478
# 4           5           0.10        1.0  0.519864         0.809187
# 5           5           0.05        0.5  0.519511         0.856046
# 6           3           0.10        0.5  0.518913         0.885081
# 7          10           0.05        0.5  0.517755         0.821818
# 8          10           0.05        1.0  0.517514         0.797909
# 9          10           0.01        0.3  0.516919         0.855212
# 10          5           0.10        0.3  0.515982         0.812950
# 11          5           0.10        0.5  0.515868         0.832402
# 12          3           0.05        0.5  0.513401         0.892340
# 13         10           0.10        1.0  0.511708         0.807207
# 14          3           0.05        0.3  0.511573         0.881391
# 15          3           0.05        1.0  0.510460         0.895178
# 16         10           0.05        0.3  0.510169         0.836190
# 17          3           0.10        1.0  0.506857         0.883576
# 18         10           0.10        0.5  0.506388         0.828897
# 19         10           0.10        0.3  0.500562         0.764605
# 20          3           0.10        0.3  0.499115         0.847695
# 21          5           0.01        0.3  0.498768         0.946262
# 22          5           0.01        0.5  0.498168         0.923077
# 23          5           0.01        1.0  0.493842         0.936916
# 24          3           0.01        0.5  0.436031         0.994048
# 25          3           0.01        1.0  0.435010         0.994030
# 26          3           0.01        0.3  0.435010         0.994030
#
#     recall_score                                             report  \
# 0       0.387960                precision    recall  f1-score   ...
# 1       0.381271                precision    recall  f1-score   ...
# 2       0.376254                precision    recall  f1-score   ...
# 3       0.369565                precision    recall  f1-score   ...
# 4       0.382943                precision    recall  f1-score   ...
# 5       0.372910                precision    recall  f1-score   ...
# 6       0.367057                precision    recall  f1-score   ...
# 7       0.377926                precision    recall  f1-score   ...
# 8       0.382943                precision    recall  f1-score   ...
# 9       0.370401                precision    recall  f1-score   ...
# 10      0.377926                precision    recall  f1-score   ...
# 11      0.373746                precision    recall  f1-score   ...
# 12      0.360368                precision    recall  f1-score   ...
# 13      0.374582                precision    recall  f1-score   ...
# 14      0.360368                precision    recall  f1-score   ...
# 15      0.357023                precision    recall  f1-score   ...
# 16      0.367057                precision    recall  f1-score   ...
# 17      0.355351                precision    recall  f1-score   ...
# 18      0.364548                precision    recall  f1-score   ...
# 19      0.372074                precision    recall  f1-score   ...
# 20      0.353679                precision    recall  f1-score   ...
# 21      0.338629                precision    recall  f1-score   ...
# 22      0.341137                precision    recall  f1-score   ...
# 23      0.335284                precision    recall  f1-score   ...
# 24      0.279264                precision    recall  f1-score   ...
# 25      0.278428                precision    recall  f1-score   ...
# 26      0.278428                precision    recall  f1-score   ...
#
#     train_time_s
# 0     585.976552
# 1     603.601475
# 2     336.453116
# 3     364.551504
# 4     249.431554
# 5     401.940874
# 6     329.496894
# 7     241.418152
# 8     190.084901
# 9     601.456531
# 10    177.387627
# 11    236.129105
# 12    410.580981
# 13    138.389326
# 14    411.280887
# 15    378.515317
# 16    230.810931
# 17    266.454969
# 18    140.554891
# 19    201.658026
# 20    268.206794
# 21    465.469520
# 22    466.927550
# 23    433.928182
# 24    412.973907
# 25    385.256912
# 26    408.485634

# %%
df_results.sort_values('recall_score', ascending=False)
# Out:
#     max_depth  learning_rate  subsample  f1_score  precision_score  \
# 0          10           0.01        1.0  0.526973         0.821239
# 8          10           0.05        1.0  0.517514         0.797909
# 4           5           0.10        1.0  0.519864         0.809187
# 1          10           0.01        0.5  0.524741         0.841328
# 7          10           0.05        0.5  0.517755         0.821818
# 10          5           0.10        0.3  0.515982         0.812950
# 2           5           0.05        1.0  0.522952         0.857143
# 13         10           0.10        1.0  0.511708         0.807207
# 11          5           0.10        0.5  0.515868         0.832402
# 5           5           0.05        0.5  0.519511         0.856046
# 19         10           0.10        0.3  0.500562         0.764605
# 9          10           0.01        0.3  0.516919         0.855212
# 3           5           0.05        0.3  0.520612         0.880478
# 6           3           0.10        0.5  0.518913         0.885081
# 16         10           0.05        0.3  0.510169         0.836190
# 18         10           0.10        0.5  0.506388         0.828897
# 14          3           0.05        0.3  0.511573         0.881391
# 12          3           0.05        0.5  0.513401         0.892340
# 15          3           0.05        1.0  0.510460         0.895178
# 17          3           0.10        1.0  0.506857         0.883576
# 20          3           0.10        0.3  0.499115         0.847695
# 22          5           0.01        0.5  0.498168         0.923077
# 21          5           0.01        0.3  0.498768         0.946262
# 23          5           0.01        1.0  0.493842         0.936916
# 24          3           0.01        0.5  0.436031         0.994048
# 25          3           0.01        1.0  0.435010         0.994030
# 26          3           0.01        0.3  0.435010         0.994030
#
#     recall_score                                             report  \
# 0       0.387960                precision    recall  f1-score   ...
# 8       0.382943                precision    recall  f1-score   ...
# 4       0.382943                precision    recall  f1-score   ...
# 1       0.381271                precision    recall  f1-score   ...
# 7       0.377926                precision    recall  f1-score   ...
# 10      0.377926                precision    recall  f1-score   ...
# 2       0.376254                precision    recall  f1-score   ...
# 13      0.374582                precision    recall  f1-score   ...
# 11      0.373746                precision    recall  f1-score   ...
# 5       0.372910                precision    recall  f1-score   ...
# 19      0.372074                precision    recall  f1-score   ...
# 9       0.370401                precision    recall  f1-score   ...
# 3       0.369565                precision    recall  f1-score   ...
# 6       0.367057                precision    recall  f1-score   ...
# 16      0.367057                precision    recall  f1-score   ...
# 18      0.364548                precision    recall  f1-score   ...
# 14      0.360368                precision    recall  f1-score   ...
# 12      0.360368                precision    recall  f1-score   ...
# 15      0.357023                precision    recall  f1-score   ...
# 17      0.355351                precision    recall  f1-score   ...
# 20      0.353679                precision    recall  f1-score   ...
# 22      0.341137                precision    recall  f1-score   ...
# 21      0.338629                precision    recall  f1-score   ...
# 23      0.335284                precision    recall  f1-score   ...
# 24      0.279264                precision    recall  f1-score   ...
# 25      0.278428                precision    recall  f1-score   ...
# 26      0.278428                precision    recall  f1-score   ...
#
#     train_time_s
# 0     585.976552
# 8     190.084901
# 4     249.431554
# 1     603.601475
# 7     241.418152
# 10    177.387627
# 2     336.453116
# 13    138.389326
# 11    236.129105
# 5     401.940874
# 19    201.658026
# 9     601.456531
# 3     364.551504
# 6     329.496894
# 16    230.810931
# 18    140.554891
# 14    411.280887
# 12    410.580981
# 15    378.515317
# 17    266.454969
# 20    268.206794
# 22    466.927550
# 21    465.469520
# 23    433.928182
# 24    412.973907
# 25    385.256912
# 26    408.485634
